# %%
#install libirarys
import pandas as pd
import numpy as np
import matplotlib.pyplot as mplt
import seaborn as sbrn
from mpl_toolkits.mplot3d import Axes3D
sbrn.set()
df = pd.read_csv("Student_Performance_2026.csv")

# %%
#desplay all data
df.head(-1)
# Out:
#     student_ID   Age  Gender  daily_screen_time_hours  social_media_hours  \
# 0         S011  23.0  Female                      6.2                 2.5
# 1         S012  24.0  Female                      4.9                 2.0
# 2         S013   NaN  Female                      7.9                 3.2
# 3         S014  17.0    Male                     10.0                 4.0
# 4         S015  23.0  Female                      7.7                 3.1
# ..         ...   ...     ...                      ...                 ...
# 540       S551  22.0  Female                      5.6                 2.2
# 541       S552  17.0    Male                      4.1                 1.6
# 542       S553  24.0  Female                      6.4                 2.6
# 543       S554  17.0    Male                      8.3                 3.3
# 544       S555  21.0  Female                      9.8                 3.9
#
#      online_study_hours  gaming_hours  sleep_hours  attendance_percentage  \
# ...

# %%
#check for outliers
mplt.figure(figsize=(6,2))
sbrn.boxplot(x=df['Age'])
mplt.title("age")
mplt.show()

# %%
#check for outliers
mplt.figure(figsize=(6,2))
sbrn.boxplot(x=df['daily_screen_time_hours'])
mplt.title("daily_screen_time_hours")
mplt.show()

# %%
#check for outliers
mplt.figure(figsize=(6,2))
sbrn.boxplot(x=df['social_media_hours'])
mplt.title("social_media_hours")
mplt.show()

# %%
#check for outliers
mplt.figure(figsize=(6,2))
sbrn.boxplot(x=df['online_study_hours'])
mplt.title("online_study_hours")
mplt.show()

# %%
#check for outliers
mplt.figure(figsize=(6,2))
sbrn.boxplot(x=df['gaming_hours'])
mplt.title("gaming_hours")
mplt.show()

# %%
#check missing data
df.isna().sum()
#some data are missing
# Out:
# student_ID                 0
# Age                        1
# Gender                     0
# daily_screen_time_hours    1
# social_media_hours         0
# online_study_hours         2
# gaming_hours               0
# sleep_hours                0
# attendance_percentage      0
# offline_study_hours        0
# previous_sem_CGPA          1
# current_sem_CGPA           1
# dtype: int64

# %%
df.isna()
# Out:
#      student_ID    Age  Gender  daily_screen_time_hours  social_media_hours  \
# 0         False  False   False                    False               False
# 1         False  False   False                    False               False
# 2         False   True   False                    False               False
# 3         False  False   False                    False               False
# 4         False  False   False                    False               False
# ..          ...    ...     ...                      ...                 ...
# 541       False  False   False                    False               False
# 542       False  False   False                    False               False
# 543       False  False   False                    False               False
# 544       False  False   False                    False               False
# 545       False  False   False                    False               False
#
# ...

# %%
df.duplicated()[df.duplicated()==True]
# Out:
# Series([], dtype: bool)

# %%
#num of instances and features(rows ,columns)
print("Shape (rows, columns): ", df.shape,)
print("number of rows: ", df.shape[0])
print("number of columns: ", df.shape[1])
# Out:
# Shape (rows, columns):  (546, 12)
# number of rows:  546
# number of columns:  12

# %%
#data types in file
df.dtypes
# Out:
# student_ID                     str
# Age                        float64
# Gender                         str
# daily_screen_time_hours    float64
# social_media_hours         float64
# online_study_hours         float64
# gaming_hours               float64
# sleep_hours                float64
# attendance_percentage        int64
# offline_study_hours        float64
# previous_sem_CGPA          float64
# current_sem_CGPA           float64
# dtype: object

# %%
#summary
df.describe()
# Out:
#               Age  daily_screen_time_hours  social_media_hours  \
# count  545.000000               545.000000          546.000000
# mean    20.952294                 7.114128            2.843773
# std      2.587001                 1.772970            0.712978
# min     17.000000                 4.000000            1.600000
# 25%     19.000000                 5.600000            2.200000
# 50%     21.000000                 7.200000            2.900000
# 75%     23.000000                 8.600000            3.400000
# max     25.000000                10.000000            4.000000
#
#        online_study_hours  gaming_hours  sleep_hours  attendance_percentage  \
# count          544.000000    546.000000   546.000000             546.000000
# mean             2.899816      1.422711     6.696886              72.970696
# std              1.771584      0.357921     0.947197              11.747772
# min              0.000000      0.800000     5.000000              55.000000
# ...

# %%
mplt.figure(figsize=(8,5))
sbrn.histplot(df['Age'], bins=9)
mplt.title("age distribution")
mplt.xlabel("age")
mplt.show()

# %%
mplt.figure(figsize=(8,5))
sbrn.histplot(df['daily_screen_time_hours'], bins=20)
mplt.title("screen time distribution")
mplt.xlabel("daily screen time")
mplt.show()

# %%
mplt.figure(figsize=(8,5))
sbrn.histplot(df['social_media_hours'], bins=20)
mplt.title("social media hours distribution")
mplt.xlabel("social media hours")
mplt.show()

# %%
mplt.figure(figsize=(8,5))
sbrn.histplot(df['online_study_hours'], bins=20)
mplt.title("online_study_hours distribution")
mplt.xlabel("online_study_hours")
mplt.show()

# %%
mplt.figure(figsize=(8,5))
sbrn.histplot(df['gaming_hours'], bins=10)
mplt.title("gaming_hours distribution")
mplt.xlabel("gaming_hours")
mplt.show()

# %%
mplt.figure(figsize=(8,5))
sbrn.histplot(df['sleep_hours'], bins=20)
mplt.title("sleep_hours distribution")
mplt.xlabel("sleep_hours")
mplt.show()

# %%
mplt.figure(figsize=(8,5))
sbrn.histplot(df['attendance_percentage'], bins=20)
mplt.title("attendance_percentage distribution")
mplt.xlabel("attendance_percentage")
mplt.show()

# %%
mplt.figure(figsize=(8,5))
sbrn.histplot(df['offline_study_hours'], bins=14)
mplt.title("offline_study_hours distribution")
mplt.xlabel("offline_study_hours")
mplt.show()

# %%
mplt.figure(figsize=(8,5))
sbrn.histplot(df['previous_sem_CGPA'], bins=20)
mplt.title("previous_sem_CGPA distribution")
mplt.xlabel("previous_sem_CGPA")
mplt.show()

# %%
mplt.figure(figsize=(8,5))
sbrn.histplot(df['current_sem_CGPA'], bins=20)
mplt.title("current_sem_CGPA distribution")
mplt.xlabel("current_sem_CGPA")
mplt.show()

# %%
fig =mplt.figure(figsize=(8,7))
ax = fig.add_subplot(111, projection='3d')
x=df.Age
y=df.previous_sem_CGPA
z=df.current_sem_CGPA
ax.scatter3D(x, y, z, color='blue', marker='o')
mplt.xlabel("age")
mplt.ylabel("previous semester gpa")
ax.set_zlabel("current term gpa")
mplt.title("age to previous term gpa")
mplt.show()

# %%
fig =mplt.figure(figsize=(8,7))
ax = fig.add_subplot(111, projection='3d')
x=df.daily_screen_time_hours
y=df.previous_sem_CGPA
z=df.current_sem_CGPA
ax.scatter3D(x, y, z, color='blue', marker='o')
mplt.xlabel("daily screen time")
mplt.ylabel("previous semester gpa")
ax.set_zlabel("current term gpa")
mplt.title("to previous term gpa")
mplt.show()

# %%
fig =mplt.figure(figsize=(8,7))
ax = fig.add_subplot(111, projection='3d')
x=df.social_media_hours
y=df.previous_sem_CGPA
z=df.current_sem_CGPA
ax.scatter3D(x, y, z, color='blue', marker='o')
mplt.xlabel("social_media_hours")
mplt.ylabel("previous semester gpa")
ax.set_zlabel("current term gpa")
mplt.title("social_media_hours to previous term gpa")
mplt.show()

# %%
fig =mplt.figure(figsize=(8,7))
ax = fig.add_subplot(111, projection='3d')
x=df.online_study_hours
y=df.previous_sem_CGPA
z=df.current_sem_CGPA
ax.scatter3D(x, y, z, color='blue', marker='o')
mplt.xlabel("online_study_hours")
mplt.ylabel("previous semester gpa")
ax.set_zlabel("current term gpa")
mplt.title("online_study_hours to previous term gpa")
mplt.show()

# %%
fig =mplt.figure(figsize=(8,7))
ax = fig.add_subplot(111, projection='3d')
x=df.gaming_hours
y=df.previous_sem_CGPA
z=df.current_sem_CGPA
ax.scatter3D(x, y, z, color='blue', marker='o')
mplt.xlabel("gaming_hours")
mplt.ylabel("previous semester gpa")
ax.set_zlabel("current term gpa")
mplt.title("gaming_hours to previous term gpa")
mplt.show()

# %%
fig =mplt.figure(figsize=(8,7))
ax = fig.add_subplot(111, projection='3d')
x=df.sleep_hours
y=df.previous_sem_CGPA
z=df.current_sem_CGPA
ax.scatter3D(x, y, z, color='blue', marker='o')
mplt.xlabel("sleep_hours")
mplt.ylabel("previous semester gpa")
ax.set_zlabel("current term gpa")
mplt.title("sleep_hours to previous term gpa")
mplt.show()

# %%
fig =mplt.figure(figsize=(8,7))
ax = fig.add_subplot(111, projection='3d')
x=df.attendance_percentage
y=df.previous_sem_CGPA
z=df.current_sem_CGPA
ax.scatter3D(x, y, z, color='blue', marker='o')
mplt.xlabel("attendance_percentage")
mplt.ylabel("previous semester gpa")
ax.set_zlabel("current term gpa")
mplt.title("attendance_percentage to previous term gpa")
mplt.show()

# %%
fig =mplt.figure(figsize=(8,7))
ax = fig.add_subplot(111, projection='3d')
x=df.offline_study_hours
y=df.previous_sem_CGPA
z=df.current_sem_CGPA
ax.scatter3D(x, y, z, color='blue', marker='o')
mplt.xlabel("offline_study_hours")
mplt.ylabel("previous semester gpa")
ax.set_zlabel("current term gpa")
mplt.title("offline_study_hours to previous term gpa")
mplt.show()

# %%
mplt.figure(figsize=(10,10))
sbrn.heatmap(df[['Age','daily_screen_time_hours','social_media_hours','online_study_hours','gaming_hours','sleep_hours','attendance_percentage','offline_study_hours','previous_sem_CGPA','current_sem_CGPA']].corr(), annot=True)
mplt.title("attendance Correlation Matrix")
mplt.show()
